# %%
""" 
The pseudoinverse of a matrix is defined as: 

Inverse(Transpose of Matrix X * Matrix X) * Transpose of Matrix X

This form applies to tall matrices with full column rank.

"""

import matplotlib.pyplot as plt
from reusing_matrices import Matrix

# %%
"""
Example 1

[(1, 0),(3, -1),(4, 5)]

Inverse(Transpose of Matrix X * Matrix X) * Transpose of Matrix X * y matrix  = the answer

Matrix X is made up of the coefficients of m and b, after plugging in the x values.

This is a linear fit

"""

x = Matrix([[1, 1], [3, 1], [4, 1]])
y = Matrix([[0],[-1],[5]])

x_t = Matrix([[1, 0], [3, -1], [4, 5]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[1, 0], [3, -1], [4, 5]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()


# y = 4.375x -12.09375 is the answers
# Out:
# [4.375]
# [-12.09375]
# ''

# %%
#  [(−2, 3),(1, 0),(3, −1),(4, 5)]
# linear fit

x = Matrix([[-2, 1], [1, 1], [3, 1], [4,1]])
y = Matrix([[3],[0],[-1],[5]])

x_t = Matrix([[-2, 1], [1, 1], [3, 1], [4,1]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[-2, 1], [1, 1], [3, 1], [4,1]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()

# y = 0.023809523809523836x + 1.7142857142857142
# Out:
# [0.023809523809523836]
# [1.7142857142857142]

# %%
#[(−2, 3),(1, 0),(3, −1),(4, 5)]
# Quadratic fit

x = Matrix([[4, -2, 1], [1,1,1], [9,3,1], [16,4,1]])
y = Matrix([[3],[0],[-1],[5]])

x_t = Matrix([[4, -2, 1], [1,1,1], [9,3,1], [16,4,1]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[4, -2, 1], [1,1,1], [9,3,1], [16,4,1]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()
# Out:
# [0.5227272727272727]
# [-0.9469696969696969]
# [-0.7499999999999999]

# %%
#  (−3, −4),(−2, 3),(1, 0),(3, −1), (4, 5)
# Quadratic fit

x = Matrix([[9, -3, 1], [4,-2,1], [1,1,1], [9,3,1], [16,4,1]])
y = Matrix([[-4],[3],[0],[-1],[5]])

x_t = Matrix([[9, -3, 1], [4,-2,1], [1,1,1], [9,3,1], [16,4,1]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[9, -3, 1], [4,-2,1], [1,1,1], [9,3,1], [16,4,1]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()
# Out:
# [0.04431599229287092]
# [0.529865125240848]
# [-0.06358381502890165]

# %%
#  [(−3, −4),(−2, 3),(3, −1), (1, 0),(4, 5)]
# Cubic Fit

x = Matrix([[-27, 9,-3, 1], [-8,4,-2,1], [27,9,3,1], [1,1,1,1], [64,16,4,1]])
y = Matrix([[-4],[3],[-1],[0],[5]])

x_t = Matrix([[-27, 9,-3, 1], [-8,4,-2,1], [27,9,3,1], [1,1,1,1], [64,16,4,1]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[-27, 9,-3, 1], [-8,4,-2,1], [27,9,3,1], [1,1,1,1], [64,16,4,1]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()

# beautiful fit!
# Out:
# [0.3478854024556618]
# [-0.6011823556161888]
# [-2.6352887676216454]
# [2.9045020463847164]

# %%
# (−2, 3, −3),(1, 0, −4),(3, −1, 2), (4, 5, 3)
# z = ax + by + c

x = Matrix([[-2,3,1], [1,0,1], [3,-1,1], [4,5,1]]) # No longer x, but rather vars (variables), but x for ease
z = Matrix([[-3],[-4],[2],[3]])

x_t = Matrix([[-2,3,1], [1,0,1], [3,-1,1], [4,5,1]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[-2,3,1], [1,0,1], [3,-1,1], [4,5,1]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(z)
pseudoinverse.show()
# Out:
# [1.0879581151832463]
# [0.30575916230366507]
# [-2.667015706806282]
