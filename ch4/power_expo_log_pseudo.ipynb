# %%
from reusing_matrices import Matrix
import math

# Exercise 1, power reg, [(1, 0.2),(2, 0.3),(3, 0.5)]

x = Matrix([[1,math.log(1)],[1,math.log(2)],[1,math.log(3)]])
y = Matrix([[math.log(0.2)],[math.log(0.3)],[math.log(0.5)]])

x_t = Matrix([[1,math.log(1)],[1,math.log(2)],[1,math.log(3)]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[1,math.log(1)],[1,math.log(2)],[1,math.log(3)]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()
# Out:
# [-1.6509686328833446]
# [0.8072221892334606]

# %%
# Exercise 2, expo reg, [(1, 0.2),(2, 0.3), (3, 0.5)]

x = Matrix([[1,1],[1,2],[1,3]])
y = Matrix([[math.log(0.2)],[math.log(0.3)],[math.log(0.5)]])

x_t = Matrix([[1,1],[1,2],[1,3]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[1,1],[1,2],[1,3]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()
# Out:
# [-2.0851433643141495]
# [0.4581453659370775]

# %%
# Exercise 3, log reg, [(1, 0.2),(2, 0.3), (3, 0.5)]

x = Matrix([[1,1],[2,1],[3,1]])
y = Matrix([[-math.log(4)],[-math.log((1/0.3)-1)],[-math.log(1)]])

x_t = Matrix([[1,1],[2,1],[3,1]])
x_t.transpose()

xtx = x_t.matrix_multiply(x)
xtx.inverse_matrix_via_rref()

x_t_for_right = Matrix([[1,1],[2,1],[3,1]])
x_t_for_right.transpose()

pseudoinverse = xtx.matrix_multiply(x_t_for_right)
#pseudoinverse.show()

pseudoinverse.matrix_multiply(y)
pseudoinverse.show()
# Out:
# [0.6931471805599451]
# [-2.130825101622255]
